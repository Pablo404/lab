# %% [markdown]
# Repaso tipos de variables

# %%
x = 3
y = 3.5
z = 'tres'

# %%
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'float'>

# %%
isinstance(x, float)
# Out:
# False

# %%
float(x)
# Out:
# 3.0

# %%
float(z)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-1d458cb500df> in <module>()
# ----> 1 float(z)
#
# ValueError: could not convert string to float: 'tres'

# %% [markdown]
# Operaciones

# %%
x + y
# Out:
# 6.5

# %%
str(x) + z
# Out:
# '3tres'

# %%
a = 'Hola estoy practicando'

# %%
a[0] = 'X'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-1f93adba677e> in <module>()
# ----> 1 a[0] = 'X'
#
# TypeError: 'str' object does not support item assignment

# %%
x % y
# Out:
# 3.0

# %%
a
# Out:
# 'Hola estoy practicando'

# %%
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
a.lower??

# %%
a.lower()
# Out:
# 'hola estoy practicando'

# %%
a.rsplit??

# %%
a.rsplit()
# Out:
# ['Hola', 'estoy', 'practicando']

# %%
b = 'How are you?'

# %%
b.replace('?', '')
# Out:
# 'How are you'

# %%
a.lower().rsplit()
# Out:
# ['hola', 'estoy', 'practicando']
