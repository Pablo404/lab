# %%
def print_mensaje():
    print("Hola")

# %%
print_mensaje()
# Out:
# Hola

# %%
def print_mensaje(mensaje):
    print(mensaje)

# %%
print_mensaje('Hola alumnos')
# Out:
# Hola alumnos

# %%
print_mensaje()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-d7a69eefe739> in <module>()
# ----> 1 print_mensaje()
#
# TypeError: print_mensaje() missing 1 required positional argument: 'mensaje'

# %%
def print_mensaje(mensaje='Hola'):
    print(mensaje)

# %%
print_mensaje()
# Out:
# Hola

# %%
print_mensaje('Hola a todos. Feliz fin de semana')
# Out:
# Hola a todos. Feliz fin de semana

# %%
def print_mensaje(nombre, saludo='Hola'):
    print(saludo, nombre)

# %%
print_mensaje('Miguel', 'Adios')
# Out:
# Adios Miguel

# %%
print_mensaje('Lurdes')
# Out:
# Hola Lurdes

# %%
print_mensaje(nombre='Carlos', saludo='Que tal')
# Out:
# Que tal Carlos

# %%
print_mensaje()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-d7a69eefe739> in <module>()
# ----> 1 print_mensaje()
#
# TypeError: print_mensaje() missing 1 required positional argument: 'nombre'

# %%
def print_mensaje(saludo='Hola', nombre):
    print(saludo, nombre)
# Out:
#   File "<ipython-input-20-cc478b1a7e4c>", line 1
#     def print_mensaje(saludo='Hola', nombre):
#                      ^
# SyntaxError: non-default argument follows default argument

# %%
def print_mensaje(nombre, saludo='Hola'):
    print(saludo, nombre)

# %%
print_mensaje(saludo='Adios',nombre='Josu')
# Out:
# Adios Josu

# %%
def print_mensaje(nombre='a todos', saludo='Hola'):
    print(saludo, nombre)

# %%
print_mensaje('Miguel','Adios')
# Out:
# Adios Miguel
