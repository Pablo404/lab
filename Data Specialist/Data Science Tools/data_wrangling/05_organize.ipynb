# %%
SANDBOX_NAME = 'fesc'# Sandbox Name
DATA_PATH = "/data/sandboxes/"+SANDBOX_NAME+"/data/"

# %%
from google.colab import drive

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # Organizar datos
#
# Otra de las fases del proceso de data wrangling consiste en dar una estructura a los datos, normálmente esta fase conlleva las siguientes operaciones:
#
# - Establecer índices, renombrar columnas.
#
# - Ordenar valores.
#
# - Eliminar duplicados
#
# - Filtrar información
#
# - Añadir/eliminar registros y/o columnas.
#
# - Editar información
#
# - Modificar la estructura de los datos

# %% [markdown]
# ## Establecer índices, renombrar columnas

# %%
import pandas as pd
import numpy as np
from collections import OrderedDict

# %% [markdown]
# Tomamos como ejemplo de nuevo el dataset de pokemon

# %%
#pokemon = spark.read.csv(DATA_PATH+'pokemon.csv', header=True, inferSchema=True).toPandas()

# Local read
pokemon = pd.read_csv('/content/drive/My Drive/Data/pokemon.csv')

pokemon.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %% [markdown]
# En este caso podríamos querer usar el nombre (Name) como índice de la tabla, lo haríamos mediante el método `set_index()`

# %%
pokemon.set_index('Name',inplace=True)
pokemon.head()
# Out:
#                # Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Bulbasaur      1  Grass  Poison  45      49       49       65       65     45
# Ivysaur        2  Grass  Poison  60      62       63       80       80     60
# Venusaur       3  Grass  Poison  80      82       83      100      100     80
# Mega Venusaur  4  Grass  Poison  80     100      123      122      120     80
# Charmander     5   Fire     NaN  39      52       43       60       50     65
#
#                Generation  Legendary
# Name
# Bulbasaur               1      False
# Ivysaur                 1      False
# Venusaur                1      False
# Mega Venusaur           1      False
# Charmander              1      False

# %% [markdown]
# Podemos volver al índice numérico con `reset_index`

# %%
pokemon.reset_index(inplace=True)
pokemon.head()
# Out:
#             Name  # Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0      Bulbasaur  1  Grass  Poison  45      49       49       65       65
# 1        Ivysaur  2  Grass  Poison  60      62       63       80       80
# 2       Venusaur  3  Grass  Poison  80      82       83      100      100
# 3  Mega Venusaur  4  Grass  Poison  80     100      123      122      120
# 4     Charmander  5   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %% [markdown]
# Para modificar el nombre de las columnas tenemos estas opciones

# %% [markdown]
# Pasar toda la lista de nombres, con la modificación deseada, en este caso cambiar Name a Nombre

# %%
pokemon.columns=[x.lower() for x in pokemon.columns]

# %%
pokemon.columns
# Out:
# Index(['name', '#', 'type 1', 'type 2', 'hp', 'attack', 'defense', 'sp. atk',
#        'sp. def', 'speed', 'generation', 'legendary'],
#       dtype='object')

# %%
pokemon.head()
# Out:
#             name  # type 1  type 2  hp  attack  defense  sp. atk  sp. def  \
# 0      Bulbasaur  1  Grass  Poison  45      49       49       65       65
# 1        Ivysaur  2  Grass  Poison  60      62       63       80       80
# 2       Venusaur  3  Grass  Poison  80      82       83      100      100
# 3  Mega Venusaur  4  Grass  Poison  80     100      123      122      120
# 4     Charmander  5   Fire     NaN  39      52       43       60       50
#
#    speed  generation  legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
pokemon.columns=[x.lower() for x in pokemon.columns]
pokemon.columns
# Out:
# Index(['name', '#', 'type 1', 'type 2', 'hp', 'attack', 'defense', 'sp. atk',
#        'sp. def', 'speed', 'generation', 'legendary'],
#       dtype='object')

# %%
pokemon.columns = [x.lower().replace(' ','_').replace('.','') for x in pokemon.columns]
pokemon.columns
# Out:
# Index(['name', '#', 'type_1', 'type_2', 'hp', 'attack', 'defense', 'sp_atk',
#        'sp_def', 'speed', 'generation', 'legendary'],
#       dtype='object')

# %%
pokemon.columns = ['Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk','Sp. Def', 'Speed', 'Generation', 'Legendary']

print(pokemon.columns)

# %% [markdown]
# Pasar un diccionario con las modificaciones

# %%
pokemon.rename(columns= {'name' : 'name_'}, head()
print (pokemon.columns)
# Out:
#   File "<ipython-input-22-40675b717bfc>", line 2
#     print (pokemon.columns)
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# El método rename también permite modificar el nombre del índice de un registro, como vemos en el siguiente ejemplo.

# %% [markdown]
# Comprobamos el valor del índice de Ivysaur, que es 1

# %%
pokemon.head()
# Out:
#             name  # type_1  type_2  hp  attack  defense  sp_atk  sp_def  \
# 0      Bulbasaur  1  Grass  Poison  45      49       49      65      65
# 1        Ivysaur  2  Grass  Poison  60      62       63      80      80
# 2       Venusaur  3  Grass  Poison  80      82       83     100     100
# 3  Mega Venusaur  4  Grass  Poison  80     100      123     122     120
# 4     Charmander  5   Fire     NaN  39      52       43      60      50
#
#    speed  generation  legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %% [markdown]
# Modificamos el nombre del índice 1 a 3

# %%
pokemon.rename(index={1:3}).head()
# Out:
#             name  # type_1  type_2  hp  attack  defense  sp_atk  sp_def  \
# 0      Bulbasaur  1  Grass  Poison  45      49       49      65      65
# 3        Ivysaur  2  Grass  Poison  60      62       63      80      80
# 2       Venusaur  3  Grass  Poison  80      82       83     100     100
# 3  Mega Venusaur  4  Grass  Poison  80     100      123     122     120
# 4     Charmander  5   Fire     NaN  39      52       43      60      50
#
#    speed  generation  legendary
# 0     45           1      False
# 3     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %% [markdown]
# ## Ordernar
#
# Ordenar de forma ascendete/descendente en función de los datos o índices que acabamos de crear, es útil para otras operaciones ya que acelera las búsquedas dentro del dataset

# %% [markdown]
# Establecemos el Name como índice de nuevo de cara a los siguientes ejercicios.
# Vemos que el índice de la tabla(nombre del pokemon) no está ordenado alfabéticamente

# %%
pokemon.set_index('name',inplace=True)
pokemon.head()
# Out:
#                # type_1  type_2  hp  attack  defense  sp_atk  sp_def  speed  \
# name
# Bulbasaur      1  Grass  Poison  45      49       49      65      65     45
# Ivysaur        2  Grass  Poison  60      62       63      80      80     60
# Venusaur       3  Grass  Poison  80      82       83     100     100     80
# Mega Venusaur  4  Grass  Poison  80     100      123     122     120     80
# Charmander     5   Fire     NaN  39      52       43      60      50     65
#
#                generation  legendary
# name
# Bulbasaur               1      False
# Ivysaur                 1      False
# Venusaur                1      False
# Mega Venusaur           1      False
# Charmander              1      False

# %% [markdown]
# Aplicamos una ordenación por índice

# %%
pokemon.sort_index(inplace=True)
pokemon.head()
# Out:
#                          #   type_1 type_2  hp  attack  defense  sp_atk  \
# name
# Abomasnow              511    Grass    Ice  90      92       75      92
# Abra                    69  Psychic    NaN  25      20       15     105
# Absol                  393     Dark    NaN  65     130       60      75
# Accelgor               679      Bug    NaN  80      70       40     100
# Aegislash Blade Forme  751    Steel  Ghost  60     150       50     150
#
#                        sp_def  speed  generation  legendary
# name
# Abomasnow                  85     60           4      False
# Abra                       55     90           1      False
# Absol                      60     75           3      False
# Accelgor                   60    145           5      False
# Aegislash Blade Forme      50     60           6      False

# %% [markdown]
# Para aplicar el sort en ordern inverso

# %%
pokemon.sort_index(ascending=False).head()
# Out:
#                       #  type_1  type_2   hp  attack  defense  sp_atk  sp_def  \
# name
# Zygarde Half Forme  795  Dragon  Ground  108     100      121      81      95
# Zweilous            696    Dark  Dragon   72      85       70      65      70
# Zubat                47  Poison  Flying   40      45       35      30      40
# Zorua               632    Dark     NaN   40      65       40      80      40
# Zoroark             633    Dark     NaN   60     105       60     120      60
#
#                     speed  generation  legendary
# name
# Zygarde Half Forme     95           6       True
# Zweilous               58           5      False
# Zubat                  55           1      False
# Zorua                  65           5      False
# Zoroark               105           5      False

# %% [markdown]
# Igualmente podemos ordenar en funcion de los valores de las columnas

# %% [markdown]
# Ordenamos por order ascendente de ataque

# %%
pokemon.sort_values('attack').head()
# Out:
#             #  type_1 type_2   hp  attack  defense  sp_atk  sp_def  speed  \
# name
# Chansey   122  Normal    NaN  250       5        5      35     105     50
# Happiny   489  Normal    NaN  100       5        5      15      65     30
# Shuckle   231     Bug   Rock   20      10      230      10     230      5
# Blissey   262  Normal    NaN  255      10       10      75     135     55
# Magikarp  140   Water    NaN   20      10       55      15      20     80
#
#           generation  legendary
# name
# Chansey            1      False
# Happiny            4      False
# Shuckle            2      False
# Blissey            2      False
# Magikarp           1      False

# %% [markdown]
# Para aplicar un sort sobre varias columnas usando distintos tipos de orden sobre cada una de ellas.

# %%
pokemon.sort_values(['attack','defense'], ascending=[True,False])
# Out:
#                          #   type_1    type_2   hp  attack  defense  sp_atk  \
# name
# Chansey                122   Normal       NaN  250       5        5      35
# Happiny                489   Normal       NaN  100       5        5      15
# Shuckle                231      Bug      Rock   20      10      230      10
# Magikarp               140    Water       NaN   20      10       55      15
# Blissey                262   Normal       NaN  255      10       10      75
# Feebas                 382    Water       NaN   20      15       20      10
# Togepi                 190    Fairy       NaN   35      20       65      40
# Metapod                 15      Bug       NaN   50      20       55      25
# Mantyke                509    Water    Flying   45      20       50      60
# Marill                 199    Water     Fairy   70      20       50      20
# Azurill                323   Normal     Fairy   50      20       40      20
# Smeargle               255   Normal       NaN   55      20       35      20
# Ledyba                 180      Bug    Flying   40      20       30      40
# Abra                    69  Psychic       NaN   25      20       15     105
# Spewpa                 734      Bug       NaN   45      22       60      27
# Wynaut                 395  Psychic       NaN   95      23       48      23
# Bronzor                485    Steel   Psychic   57      24       86      24
# Kakuna                  18      Bug    Poison   45      25       50      25
# Mime Jr.               488  Psychic     Fairy   20      25       45      70
# Munna                  577  Psychic       NaN   76      25       45      67
# Kricketot              447      Bug       NaN   37      25       41      25
# Spoink                 357  Psychic       NaN   60      25       35      70
# Cleffa                 188    Fairy       NaN   50      25       28      45
# Ralts                  304  Psychic     Fairy   28      25       25      45
# Cottonee               607    Grass     Fairy   40      27       60      37
# Burmy                  458      Bug       NaN   40      29       45      29
# Darmanitan Zen Mode    617     Fire   Psychic  105      30      105     140
# Yamask                 624    Ghost       NaN   38      30       85      55
# Litwick                669    Ghost      Fire   50      30       55      65
# Luvdisc                406    Water       NaN   43      30       55      40
# ...                    ...      ...       ...  ...     ...      ...     ...
# Haxorus                674   Dragon       NaN   76     147       90      60
# Groudon                424   Ground       NaN  100     150      140     100
# Mega Scizor            230      Bug     Steel   70     150      140      65
# Zekrom                 708   Dragon  Electric  100     150      120     120
# Mega Swampert          284    Water    Ground  100     150      110      95
# Primal Kyogre          423    Water       NaN  100     150       90     180
# Rayquaza               426   Dragon    Flying  105     150       90     150
# Mega Mewtwo Y          165  Psychic       NaN  106     150       70     194
# Mega Absol             394     Dark       NaN   65     150       60     115
# Aegislash Blade Forme  751    Steel     Ghost   60     150       50     150
# Deoxys Normal Forme    429  Psychic       NaN   50     150       50     150
# Mega Beedrill           20      Bug    Poison   65     150       40      15
# Mega Pinsir            138      Bug    Flying   65     155      120      65
# Mega Gyarados          142    Water      Dark   95     155      109      70
# Mega Diancie           797     Rock     Fairy   50     160      110     160
# Regigigas              544   Normal       NaN  110     160      110      80
# Slaking                314   Normal       NaN  150     160      100      95
# Mega Blaziken          280     Fire  Fighting   80     160       80     130
# Hoopa Unbound          799  Psychic      Dark   80     160       60     170
# Mega Tyranitar         269     Rock      Dark  100     164      150      95
# Mega Gallade           528  Psychic  Fighting   68     165       95      65
# Mega Banette           388    Ghost       NaN   64     165       75      93
# Rampardos              455     Rock       NaN   97     165       60      65
# Mega Garchomp          495   Dragon    Ground  108     170      115     120
# Kyurem Black Kyurem    712   Dragon       Ice  125     170      100     120
# Primal Groudon         425   Ground      Fire  100     180      160     150
# Mega Rayquaza          427   Dragon    Flying  105     180      100     180
# DeoxysAttack Forme     430  Psychic       NaN   50     180       20     180
# Mega Heracross         233      Bug  Fighting   80     185      115      40
# Mega Mewtwo X          164  Psychic  Fighting  106     190      100     154
#
#                        sp_def  speed  generation  legendary
# name
# Chansey                   105     50           1      False
# Happiny                    65     30           4      False
# Shuckle                   230      5           2      False
# Magikarp                   20     80           1      False
# Blissey                   135     55           2      False
# Feebas                     55     80           3      False
# Togepi                     65     20           2      False
# Metapod                    25     30           1      False
# Mantyke                   120     50           4      False
# Marill                     50     40           2      False
# Azurill                    40     20           3      False
# Smeargle                   45     75           2      False
# Ledyba                     80     55           2      False
# Abra                       55     90           1      False
# Spewpa                     30     29           6      False
# Wynaut                     48     23           3      False
# Bronzor                    86     23           4      False
# Kakuna                     25     35           1      False
# Mime Jr.                   90     60           4      False
# Munna                      55     24           5      False
# Kricketot                  41     25           4      False
# Spoink                     80     60           3      False
# Cleffa                     55     15           2      False
# Ralts                      35     40           3      False
# Cottonee                   50     66           5      False
# Burmy                      45     36           4      False
# Darmanitan Zen Mode       105     55           5      False
# Yamask                     65     30           5      False
# Litwick                    55     20           5      False
# Luvdisc                    65     97           3      False
# ...                       ...    ...         ...        ...
# Haxorus                    70     97           5      False
# Groudon                    90     90           3       True
# Mega Scizor               100     75           2      False
# Zekrom                    100     90           5       True
# Mega Swampert             110     70           3      False
# Primal Kyogre             160     90           3       True
# Rayquaza                   90     95           3       True
# Mega Mewtwo Y             120    140           1       True
# Mega Absol                 60    115           3      False
# Aegislash Blade Forme      50     60           6      False
# Deoxys Normal Forme        50    150           3       True
# Mega Beedrill              80    145           1      False
# Mega Pinsir                90    105           1      False
# Mega Gyarados             130     81           1      False
# Mega Diancie              110    110           6       True
# Regigigas                 110    100           4       True
# Slaking                    65    100           3      False
# Mega Blaziken              80    100           3      False
# Hoopa Unbound             130     80           6       True
# Mega Tyranitar            120     71           2      False
# Mega Gallade              115    110           4      False
# Mega Banette               83     75           3      False
# Rampardos                  50     58           4      False
# Mega Garchomp              95     92           4      False
# Kyurem Black Kyurem        90     95           5       True
# Primal Groudon             90     90           3       True
# Mega Rayquaza             100    115           3       True
# DeoxysAttack Forme         20    150           3       True
# Mega Heracross            105     75           2      False
# Mega Mewtwo X             100    130           1       True
#
# [800 rows x 11 columns]

# %% [markdown]
# ## Eliminar duplicados
#
# Todos dataset son susceptibles de tener registros duplicados, total o parcialmente, lo que según cada caso puede tener sentido o no. Veamos como identificarlos y tratarlos.

# %% [markdown]
# Cargamos de nuevo el dataset

# %%
pokemon = spark.read.csv(DATA_PATH+'pokemon.csv', header=True, inferSchema=True).toPandas()

# Local read
# pokemon = pd.read_csv('../../data/pokemon.csv')

# %%
pokemon.head(3)
# Out:
#              #   type_1 type_2  hp  attack  defense  sp_atk  sp_def  speed  \
# name
# Abomasnow  511    Grass    Ice  90      92       75      92      85     60
# Abra        69  Psychic    NaN  25      20       15     105      55     90
# Absol      393     Dark    NaN  65     130       60      75      60     75
#
#            generation  legendary
# name
# Abomasnow           4      False
# Abra                1      False
# Absol               3      False

# %%
pokemon.reset_index(inplace=True)

# %%
pokemon.head(3)
# Out:
#         name    #   type_1 type_2  hp  attack  defense  sp_atk  sp_def  speed  \
# 0  Abomasnow  511    Grass    Ice  90      92       75      92      85     60
# 1       Abra   69  Psychic    NaN  25      20       15     105      55     90
# 2      Absol  393     Dark    NaN  65     130       60      75      60     75
#
#    generation  legendary
# 0           4      False
# 1           1      False
# 2           3      False

# %% [markdown]
# Mediante duplicated obtenemos si existe algún registro duplicado, a nivel de todos los campos

# %%
pokemon.duplicated().any()
# Out:
# False

# %% [markdown]
# Podemos aplicar ese filtro a un número determinado de campos

# %%
print('Are there Pokemos with the same name?','\n')
print(pokemon['name'].duplicated().any(),'\n')
print('Are there several type_1 Pokemons?','\n')
print(pokemon['type_1'].duplicated().any(),'\n')
# Out:
# Are there Pokemos with the same name?
#
# False
#
# Are there several type_1 Pokemons?
#
# True

# %% [markdown]
# Para eliminar los registros duplicados usamos `drop_duplicates`, que requiere el parámetro inplace=True para modificar el dataset original.

# %% [markdown]
# En este caso no eliminaríamos ningún registro, ya que acabamos de ver que no hay pokemons iguales

# %%
pokemon.drop_duplicates()
# Out:
#                        name    #    type_1    type_2   hp  attack  defense  \
# 0                 Abomasnow  511     Grass       Ice   90      92       75
# 1                      Abra   69   Psychic       NaN   25      20       15
# 2                     Absol  393      Dark       NaN   65     130       60
# 3                  Accelgor  679       Bug       NaN   80      70       40
# 4     Aegislash Blade Forme  751     Steel     Ghost   60     150       50
# 5    Aegislash Shield Forme  752     Steel     Ghost   60      50      150
# 6                Aerodactyl  154      Rock    Flying   80     105       65
# 7                    Aggron  333     Steel      Rock   70     110      180
# 8                     Aipom  206    Normal       NaN   55      70       55
# 9                  Alakazam   71   Psychic       NaN   55      50       45
# 10                Alomomola  656     Water       NaN  165      75       80
# 11                  Altaria  366    Dragon    Flying   75      70       90
# 12                   Amaura  769      Rock       Ice   77      59       50
# 13                  Ambipom  472    Normal       NaN   75     100       66
# 14                Amoonguss  653     Grass    Poison  114      85       70
# 15                 Ampharos  196  Electric       NaN   90      75       85
# 16                  Anorith  380      Rock       Bug   45      95       50
# 17                    Arbok   30    Poison       NaN   60      85       69
# 18                 Arcanine   65      Fire       NaN   90     110       80
# 19                   Arceus  553    Normal       NaN  120     120      120
# 20                   Archen  628      Rock    Flying   55     112       45
# 21                 Archeops  629      Rock    Flying   75     140       65
# 22                  Ariados  183       Bug    Poison   70      90       70
# 23                  Armaldo  381      Rock       Bug   75     125      100
# 24               Aromatisse  754     Fairy       NaN  101      72       72
# 25                     Aron  331     Steel      Rock   50      70      100
# 26                 Articuno  157       Ice    Flying   90      85      100
# 27                   Audino  591    Normal       NaN  103      60       86
# 28                  Aurorus  770      Rock       Ice  123      77       72
# 29                  Avalugg  790       Ice       NaN   95     117      184
# ..                      ...  ...       ...       ...  ...     ...      ...
# 770              Whirlipede  605       Bug    Poison   40      55       99
# 771                Whiscash  373     Water    Ground  110      78       73
# 772                 Whismur  318    Normal       NaN   64      51       23
# 773              Wigglytuff   46    Normal     Fairy  140      70       45
# 774                 Wingull  302     Water    Flying   40      30       30
# 775               Wobbuffet  218   Psychic       NaN  190      33       58
# 776                  Woobat  587   Psychic    Flying   55      45       43
# 777                  Wooper  210     Water    Ground   55      45       45
# 778    Wormadam Plant Cloak  459       Bug     Grass   60      59       85
# 779    Wormadam Sandy Cloak  460       Bug    Ground   60      79      105
# 780    Wormadam Trash Cloak  461       Bug     Steel   60      69       95
# 781                 Wurmple  289       Bug       NaN   45      45       35
# 782                  Wynaut  395   Psychic       NaN   95      23       48
# 783                    Xatu  193   Psychic    Flying   65      75       70
# 784                 Xerneas  793     Fairy       NaN  126     131       95
# 785                  Yamask  624     Ghost       NaN   38      30       85
# 786                   Yanma  209       Bug    Flying   65      65       45
# 787                 Yanmega  521       Bug    Flying   86      76       86
# 788                 Yveltal  794      Dark    Flying  126     131       95
# 789                Zangoose  368    Normal       NaN   73     115       60
# 790                  Zapdos  158  Electric    Flying   90      90       85
# 791               Zebstrika  583  Electric       NaN   75     100       63
# 792                  Zekrom  708    Dragon  Electric  100     150      120
# 793               Zigzagoon  287    Normal       NaN   38      30       41
# 794                 Zoroark  633      Dark       NaN   60     105       60
# 795                   Zorua  632      Dark       NaN   40      65       40
# 796                   Zubat   47    Poison    Flying   40      45       35
# 797                Zweilous  696      Dark    Dragon   72      85       70
# 798      Zygarde Half Forme  795    Dragon    Ground  108     100      121
# 799                     NaN   63  Fighting       NaN   65     105       60
#
#      sp_atk  sp_def  speed  generation  legendary
# 0        92      85     60           4      False
# 1       105      55     90           1      False
# 2        75      60     75           3      False
# 3       100      60    145           5      False
# 4       150      50     60           6      False
# 5        50     150     60           6      False
# 6        60      75    130           1      False
# 7        60      60     50           3      False
# 8        40      55     85           2      False
# 9       135      95    120           1      False
# 10       40      45     65           5      False
# 11       70     105     80           3      False
# 12       67      63     46           6      False
# 13       60      66    115           4      False
# 14       85      80     30           5      False
# 15      115      90     55           2      False
# 16       40      50     75           3      False
# 17       65      79     80           1      False
# 18      100      80     95           1      False
# 19      120     120    120           4       True
# 20       74      45     70           5      False
# 21      112      65    110           5      False
# 22       60      60     40           2      False
# 23       70      80     45           3      False
# 24       99      89     29           6      False
# 25       40      40     30           3      False
# 26       95     125     85           1       True
# 27       60      86     50           5      False
# 28       99      92     58           6      False
# 29       44      46     28           6      False
# ..      ...     ...    ...         ...        ...
# 770      40      79     47           5      False
# 771      76      71     60           3      False
# 772      51      23     28           3      False
# 773      85      50     45           1      False
# 774      55      30     85           3      False
# 775      33      58     33           2      False
# 776      55      43     72           5      False
# 777      25      25     15           2      False
# 778      79     105     36           4      False
# 779      59      85     36           4      False
# 780      69      95     36           4      False
# 781      20      30     20           3      False
# 782      23      48     23           3      False
# 783      95      70     95           2      False
# 784     131      98     99           6       True
# 785      55      65     30           5      False
# 786      75      45     95           2      False
# 787     116      56     95           4      False
# 788     131      98     99           6       True
# 789      60      60     90           3      False
# 790     125      90    100           1       True
# 791      80      63    116           5      False
# 792     120     100     90           5       True
# 793      30      41     60           3      False
# 794     120      60    105           5      False
# 795      80      40     65           5      False
# 796      30      40     55           1      False
# 797      65      70     58           5      False
# 798      81      95     95           6       True
# 799      60      70     95           1      False
#
# [800 rows x 12 columns]

# %% [markdown]
# Si aplicamos el filtro únicamente a la columna Type 1 si que encontramos duplicados, que eliminaremos,
# quedándonos únicamente con la primera ocurrencia.

# %%
pokemon.drop_duplicates(subset=['type_1'], keep='first').shape
# Out:
# (18, 12)

# %% [markdown]
# ## Aplicar filtros
#
# Aplicar filtros sobre los datos es muy útil de cara a conocer como se distribuyen nuestros datos y con ello realizar transformaciones sobre los mismos

# %% [markdown]
# Para aplicar un filtro tenemos que establecer una condición sobre los datos

# %%
pokemon[pokemon['attack'] > 150]
# Out:
#                     name    #   type_1    type_2   hp  attack  defense  \
# 141   DeoxysAttack Forme  430  Psychic       NaN   50     180       20
# 294        Hoopa Unbound  799  Psychic      Dark   80     160       60
# 339  Kyurem Black Kyurem  712   Dragon       Ice  125     170      100
# 413         Mega Banette  388    Ghost       NaN   64     165       75
# 416        Mega Blaziken  280     Fire  Fighting   80     160       80
# 420         Mega Diancie  797     Rock     Fairy   50     160      110
# 421         Mega Gallade  528  Psychic  Fighting   68     165       95
# 422        Mega Garchomp  495   Dragon    Ground  108     170      115
# 426        Mega Gyarados  142    Water      Dark   95     155      109
# 427       Mega Heracross  233      Bug  Fighting   80     185      115
# 438        Mega Mewtwo X  164  Psychic  Fighting  106     190      100
# 441          Mega Pinsir  138      Bug    Flying   65     155      120
# 442        Mega Rayquaza  427   Dragon    Flying  105     180      100
# 451       Mega Tyranitar  269     Rock      Dark  100     164      150
# 547       Primal Groudon  425   Ground      Fire  100     180      160
# 567            Rampardos  455     Rock       NaN   97     165       60
# 573            Regigigas  544   Normal       NaN  110     160      110
# 641              Slaking  314   Normal       NaN  150     160      100
#
#      sp_atk  sp_def  speed  generation  legendary
# 141     180      20    150           3       True
# 294     170     130     80           6       True
# 339     120      90     95           5       True
# 413      93      83     75           3      False
# 416     130      80    100           3      False
# 420     160     110    110           6       True
# 421      65     115    110           4      False
# 422     120      95     92           4      False
# 426      70     130     81           1      False
# 427      40     105     75           2      False
# 438     154     100    130           1       True
# 441      65      90    105           1      False
# 442     180     100    115           3       True
# 451      95     120     71           2      False
# 547     150      90     90           3       True
# 567      65      50     58           4      False
# 573      80     110    100           4       True
# 641      95      65    100           3      False

# %%
len(pokemon[pokemon['attack'] > 150])
# Out:
# 18

# %%
pokemon[pokemon['attack'] > 150].shape
# Out:
# (18, 12)

# %% [markdown]
# Los operadores lógicos se resumen en esta imagen
#
# <center><img src="img/logicaloperators.png"></center>

# %% [markdown]
# Se pueden aplicar varios condiciones simultáneamente

# %%
pokemon[(pokemon['attack'] > 110) & (pokemon['type_1'] == 'Water')]
# Out:
#               name    # type_1  type_2   hp  attack  defense  sp_atk  sp_def  \
# 118      Crawdaunt  375  Water    Dark   63     120       85      90      55
# 272       Gyarados  141  Water  Flying   95     125       79      60     100
# 325        Kingler  108  Water     NaN   55     130      115      50      50
# 426  Mega Gyarados  142  Water    Dark   95     155      109      70     130
# 447  Mega Sharpedo  350  Water    Dark   70     140       70     110      65
# 450  Mega Swampert  284  Water  Ground  100     150      110      95     110
# 509         Palkia  542  Water  Dragon   90     120      100     150     120
# 548  Primal Kyogre  423  Water     NaN  100     150       90     180     160
# 615       Sharpedo  349  Water    Dark   70     120       40      95      40
#
#      speed  generation  legendary
# 118     55           3      False
# 272     81           1      False
# 325     75           1      False
# 426     81           1      False
# 447    105           3      False
# 450     70           3      False
# 509    100           4       True
# 548     90           3       True
# 615     95           3      False

# %% [markdown]
# Para evitar tener que agrupar varios filtros usamos .isin()

# %%
pokemon[(pokemon['attack'] > 110) & (pokemon['type_1'].isin(['Water','Grass','Fire']))].shape[0]
# Out:
# 21

# %% [markdown]
# Tambien es posible usar el método `between`

# %%
pokemon[pokemon['attack'].between(110,150)]
# Out:
#                           name    #    type_1    type_2   hp  attack  defense  \
# 2                        Absol  393      Dark       NaN   65     130       60
# 4        Aegislash Blade Forme  751     Steel     Ghost   60     150       50
# 7                       Aggron  333     Steel      Rock   70     110      180
# 18                    Arcanine   65      Fire       NaN   90     110       80
# 19                      Arceus  553    Normal       NaN  120     120      120
# 20                      Archen  628      Rock    Flying   55     112       45
# 21                    Archeops  629      Rock    Flying   75     140       65
# 23                     Armaldo  381      Rock       Bug   75     125      100
# 29                     Avalugg  790       Ice       NaN   95     117      184
# 31                       Azelf  540   Psychic       NaN   75     125       70
# 36                     Banette  387     Ghost       NaN   64     115       65
# 42                     Beartic  676       Ice       NaN   95     110       80
# 53                     Bisharp  687      Dark     Steel   65     125      100
# 55                    Blaziken  279      Fire  Fighting   80     120       70
# 60                  Bouffalant  688    Normal       NaN   95     110       95
# 62                    Braviary  690    Normal    Flying  100     123       75
# 63                     Breloom  311     Grass  Fighting   60     130       80
# 74                    Cacturne  364     Grass      Dark   70     115       60
# 112                 Conkeldurr  595  Fighting       NaN  105     140       95
# 117                   Cranidos  454      Rock       NaN   67     125       40
# 118                  Crawdaunt  375     Water      Dark   63     120       85
# 129   Darmanitan Standard Mode  616      Fire       NaN  105     140       55
# 139        Deoxys Normal Forme  429   Psychic       NaN   50     150       50
# 144                     Dialga  541     Steel    Dragon  100     120      120
# 149                     Dodrio   93    Normal    Flying   60     110       70
# 151                    Donphan  252    Ground       NaN   90     120      120
# 152                   Doublade  750     Steel     Ghost   59     110      150
# 155                  Dragonite  162    Dragon    Flying   91     134       95
# 162                  Druddigon  683    Dragon       NaN   77     120       90
# 174                 Eelektross  666  Electric       NaN   85     115       80
# ..                         ...  ...       ...       ...  ...     ...      ...
# 512                    Pangoro  744  Fighting      Dark   95     124       78
# 535                     Pinsir  137       Bug       NaN   65     125      100
# 548              Primal Kyogre  423     Water       NaN  100     150       90
# 571                   Rayquaza  426    Dragon    Flying  105     150       90
# 578                   Reshiram  707    Dragon      Fire  100     120      100
# 580                     Rhydon  121    Ground      Rock  105     130      120
# 582                  Rhyperior  516    Ground      Rock  115     140      130
# 590                  Salamence  409    Dragon    Flying   95     135       80
# 595                       Sawk  600  Fighting       NaN   75     125       75
# 599                     Scizor  229       Bug     Steel   70     130      100
# 603                    Scyther  133       Bug    Flying   70     110       80
# 615                   Sharpedo  349     Water      Dark   70     120       40
# 653                    Snorlax  156    Normal       NaN  160     110       65
# 669                  Staraptor  444    Normal    Flying   85     120       70
# 675                  Stoutland  568    Normal       NaN   85     110       90
# 686                   Swampert  283     Water    Ground  100     110       90
# 702                  Terrakion  701      Rock  Fighting   91     129       90
# 704  Thundurus Incarnate Forme  705  Electric    Flying   79     115       70
# 713   Tornadus Incarnate Forme  703    Flying       NaN   79     115       70
# 721                  Trevenant  780     Ghost     Grass   85     110       76
# 728                  Tyranitar  268      Rock      Dark  100     134      110
# 729                  Tyrantrum  768      Rock    Dragon   82     121      119
# 733                   Unfezant  581    Normal    Flying   80     115       80
# 735                   Ursaring  236    Normal       NaN   90     130       75
# 754                  Volcanion  800      Fire     Water   80     110      120
# 765                    Weavile  513      Dark       Ice   70     120       65
# 784                    Xerneas  793     Fairy       NaN  126     131       95
# 788                    Yveltal  794      Dark    Flying  126     131       95
# 789                   Zangoose  368    Normal       NaN   73     115       60
# 792                     Zekrom  708    Dragon  Electric  100     150      120
#
#      sp_atk  sp_def  speed  generation  legendary
# 2        75      60     75           3      False
# 4       150      50     60           6      False
# 7        60      60     50           3      False
# 18      100      80     95           1      False
# 19      120     120    120           4       True
# 20       74      45     70           5      False
# 21      112      65    110           5      False
# 23       70      80     45           3      False
# 29       44      46     28           6      False
# 31      125      70    115           4       True
# 36       83      63     65           3      False
# 42       70      80     50           5      False
# 53       60      70     70           5      False
# 55      110      70     80           3      False
# 60       40      95     55           5      False
# 62       57      75     80           5      False
# 63       60      60     70           3      False
# 74      115      60     55           3      False
# 112      55      65     45           5      False
# 117      30      30     58           4      False
# 118      90      55     55           3      False
# 129      30      55     95           5      False
# 139     150      50    150           3       True
# 144     150     100     90           4       True
# 149      60      60    100           1      False
# 151      60      60     50           2      False
# 152      45      49     35           6      False
# 155     100     100     80           1      False
# 162      60      90     48           5      False
# 174     105      80     50           5      False
# ..      ...     ...    ...         ...        ...
# 512      69      71     58           6      False
# 535      55      70     85           1      False
# 548     180     160     90           3       True
# 571     150      90     95           3       True
# 578     150     120     90           5       True
# 580      45      45     40           1      False
# 582      55      55     40           4      False
# 590     110      80    100           3      False
# 595      30      75     85           5      False
# 599      55      80     65           2      False
# 603      55      80    105           1      False
# 615      95      40     95           3      False
# 653      65     110     30           1      False
# 669      50      60    100           4      False
# 675      45      90     80           5      False
# 686      85      90     60           3      False
# 702      72      90    108           5       True
# 704     125      80    111           5       True
# 713     125      80    111           5       True
# 721      65      82     56           6      False
# 728      95     100     61           2      False
# 729      69      59     71           6      False
# 733      65      55     93           5      False
# 735      75      75     55           2      False
# 754     130      90     70           6       True
# 765      45      85    125           4      False
# 784     131      98     99           6       True
# 788     131      98     99           6       True
# 789      60      60     90           3      False
# 792     120     100     90           5       True
#
# [123 rows x 12 columns]

# %% [markdown]
# Hasta ahora hemos visto como realizar filtros sobre el contenido, pero si queremos seleccionar por filas es necesario recurrir a los métodos `.iloc[], .loc[], .ix[]`
#
# Recordamos que .iloc[] realiza la selección de registros por el índice numérico, .loc[] a través de la etiqueta del índice e .ix[] permite el uso tanto de etiquetas como de valores numéricos, sin embargo, no se recomienda su uso ya que se encuentra deprecado desde la versión 0.20.0 de Pandas.
#
# Veamos algunos ejemplos de selección de registros con .iloc[] y .loc[]

# %% [markdown]
# Selección de un registro

# %%
pokemon.iloc[3]

# %% [markdown]
# Selección mediante intervalo

# %%
pokemon.iloc[3:6]

# %% [markdown]
# Selección mediante una lista

# %%
pokemon.iloc[[3,7,9]]

# %% [markdown]
# Selección de un registro y un único campo

# %%
pokemon.iloc[3, 1]

# %% [markdown]
# Selección de varios registros y varios campos

# %%
pokemon.iloc[[3,9,18], [1,4,5]]

# %% [markdown]
# Para poder usar el método .loc[] necesitamos que el dataframe tenga un índice con etiquetas

# %%
pokemon.set_index('name',inplace=True)
pokemon.head()
# Out:
#                          #   type_1 type_2  hp  attack  defense  sp_atk  \
# name
# Abomasnow              511    Grass    Ice  90      92       75      92
# Abra                    69  Psychic    NaN  25      20       15     105
# Absol                  393     Dark    NaN  65     130       60      75
# Accelgor               679      Bug    NaN  80      70       40     100
# Aegislash Blade Forme  751    Steel  Ghost  60     150       50     150
#
#                        sp_def  speed  generation  legendary
# name
# Abomasnow                  85     60           4      False
# Abra                       55     90           1      False
# Absol                      60     75           3      False
# Accelgor                   60    145           5      False
# Aegislash Blade Forme      50     60           6      False

# %% [markdown]
# Selección de un registro

# %%
pokemon.loc['Ivysaur']

# %% [markdown]
# Selección de varios registro

# %%
pokemon.loc[['Ivysaur','Venusaur','Charmander']]

# %% [markdown]
# Selección de varios registros y varias columnas

# %%
pokemon.loc[['Ivysaur','Venusaur','Charmander'], ['Attack','Defense']]

# %% [markdown]
# ## Añadir/eliminar registros y/o columnas
#
# En ocasiones es necesario eliminar registros o columnas que no son necesarios, veamos como hacerlo.

# %% [markdown]
# Borrado de un único registro por etiqueta

# %%
pokemon.set_index('name',inplace=True)
pokemon.head()

# %%
print('Pokemons number','\n')
print(pokemon.shape[0],'\n')
pokemon.drop('Charmander',inplace=True)
print('Pokemons number after the deletion','\n')
print(pokemon.shape[0],'\n')
# Out:
# Pokemons number
#
# 800
#
# Pokemons number after the deletion
#
# 799

# %% [markdown]
# Es posible eliminar una columna entera indicando su nombre y el eje correspondiente (axis=1)

# %% [markdown]
# Eliminamos la columna 'Generation'

# %%
pokemon.drop('generation',axis=1,inplace=True)
pokemon.head()
# Out:
#                          #   type_1 type_2  hp  attack  defense  sp_atk  \
# name
# Abomasnow              511    Grass    Ice  90      92       75      92
# Abra                    69  Psychic    NaN  25      20       15     105
# Absol                  393     Dark    NaN  65     130       60      75
# Accelgor               679      Bug    NaN  80      70       40     100
# Aegislash Blade Forme  751    Steel  Ghost  60     150       50     150
#
#                        sp_def  speed  legendary
# name
# Abomasnow                  85     60      False
# Abra                       55     90      False
# Absol                      60     75      False
# Accelgor                   60    145      False
# Aegislash Blade Forme      50     60      False

# %% [markdown]
# El borrado de columnas también es posible realizarlo mediante la built-in función `del`

# %%
del pokemon['speed']
pokemon.head()
# Out:
#                          #   type_1 type_2  hp  attack  defense  sp_atk  \
# name
# Abomasnow              511    Grass    Ice  90      92       75      92
# Abra                    69  Psychic    NaN  25      20       15     105
# Absol                  393     Dark    NaN  65     130       60      75
# Accelgor               679      Bug    NaN  80      70       40     100
# Aegislash Blade Forme  751    Steel  Ghost  60     150       50     150
#
#                        sp_def  legendary
# name
# Abomasnow                  85      False
# Abra                       55      False
# Absol                      60      False
# Accelgor                   60      False
# Aegislash Blade Forme      50      False

# %% [markdown]
# Para agregar una nueva columna haremos una asignación de un contenido a una columna que no exista

# %% [markdown]
# Creamos una nueva columna 'Level'

# %%
pokemon['Level'] = pokemon['Attack']*2
pokemon.head()

# %% [markdown]
# Si queremos añadir algún registro nuevo, tenemos que proporcinar la información para las columnas.

# %% [markdown]
# Creamos la información del nuevo pokemon

# %%
data = {'name': ['Charmander_BLUE'],
        'type_1': ['Fire'],
        'type_2': ['Water'],
        'hp': [100]}

new_pokemon = pd.DataFrame(data)

# %% [markdown]
# Añadimos el nuevo registro

# %%
pokemon = pokemon.append(new_pokemon)
pokemon[pokemon['name']=='Charmander_BLUE']
# Out:
#     #  attack  defense   hp legendary             name  sp_atk  sp_def type_1  \
# 0 NaN     NaN      NaN  100       NaN  Charmander_BLUE     NaN     NaN   Fire
# 0 NaN     NaN      NaN  100       NaN  Charmander_BLUE     NaN     NaN   Fire
#
#   type_2
# 0  Water
# 0  Water

# %% [markdown]
# ## Editar información

# %% [markdown]
# Para editar el contenido del dataframe podemos modificar toda una columna en bloque, usando el método de asignación (=)

# %%
pokemon['Speed'] = pokemon['Attack']/pokemon['Defense']
pokemon['Speed'].head()

# %% [markdown]
# También podemos editar el contenido de un registro concreto y de alguno o todos sus campos. Para ello nos basamos en los método de selección de registros .iloc/.loc antes explicados.

# %% [markdown]
# Vemos la información del pokemon del índice 10

# %%
pokemon.iloc[10]
# Out:
# #              656
# attack          75
# defense         80
# hp             165
# legendary    False
# name           NaN
# sp_atk          40
# sp_def          45
# type_1       Water
# type_2         NaN
# Name: Alomomola, dtype: object

# %% [markdown]
# Modificamos el contenido (campos 0, 1 y 4) del registro 10 asignando nueva información.

# %%
pokemon.iloc[10, [0,1,4]] = [100,130,True]

# %%
pokemon.iloc[10]
# Out:
# #              100
# attack         130
# defense         80
# hp             165
# legendary     True
# name           NaN
# sp_atk          40
# sp_def          45
# type_1       Water
# type_2         NaN
# Name: Alomomola, dtype: object

# %% [markdown]
# ## Modificar la estructura de los datos

# %% [markdown]
# ### Pivot, stack/unstack, melt
#
# Existen varias métodos que nos permiten transformar la estructura de las tablas, haciendo agrupaciones de datos, trasladando índices de columnas a filas y agrupando varias columnas en otras nuevas. Estos son los métodos pivot, stack/unstack y melt.

# %% [markdown]
# La función **pivot** se usa para crear una nueva tabla derivada a partir de otra.

# %% [markdown]
# Creamos un dataframe ejemplo

# %%
table = OrderedDict((
    ("Item", ['Item0', 'Item0', 'Item1', 'Item1']),
    ('CType',['Gold', 'Bronze', 'Gold', 'Silver']),
    ('USD',  ['1$', '2$', '3$', '4$']),
    ('EU',   ['1€', '2€', '3€', '4€'])
))
d = pd.DataFrame(table)

# %%
d
# Out:
#     Item   CType USD  EU
# 0  Item0    Gold  1$  1€
# 1  Item0  Bronze  2$  2€
# 2  Item1    Gold  3$  3€
# 3  Item1  Silver  4$  4€

# %% [markdown]
# Creamos la pivot-table

# %%
p = d.pivot(index='Item', columns='CType', values='USD')
p
# Out:
# CType Bronze Gold Silver
# Item
# Item0     2$   1$   None
# Item1   None   3$     4$

# %% [markdown]
# Hacer **stack** en un Dataframe significa mover la columna más interna (rotando el dataframe) para convertirla en el índice de fila más interno.

# %% [markdown]
# Generamos un dataframe con varios índices tanto a nivel de columna como de fila

# %%
row_idx_arr = list(zip(['r0', 'r0'], ['r-00', 'r-01']))
row_idx = pd.MultiIndex.from_tuples(row_idx_arr)


col_idx_arr = list(zip(['c0', 'c0', 'c1'], ['c-00', 'c-01', 'c-10']))
col_idx = pd.MultiIndex.from_tuples(col_idx_arr)


d = pd.DataFrame(np.arange(6).reshape(2,3), index=row_idx, columns=col_idx)
d = d.applymap(lambda x: (x // 3, x % 3))
d

# %% [markdown]
# Al hacer stack del DF estamos moviendo la columna más interior hasta el índice de las filas

# %%
s = d.stack()
s

# %% [markdown]
# Podemos deshacer la operación mediante unstack

# %%
u = d.unstack()
u

# %% [markdown]
# Por último tenemos la operación **melt**, que nos permite realizar la agrupación de varias columnas relacionadas en una nueva.

# %% [markdown]
# Creamos un dataframe

# %%
data = {'weekday': ["Monday", "Tuesday", "Wednesday", 
         "Thursday", "Friday", "Saturday", "Sunday"],
        'Person 1': [12, 6, 5, 8, 11, 6, 4],
        'Person 2': [10, 6, 11, 5, 8, 9, 12],
        'Person 3': [8, 5, 7, 3, 7, 11, 15]}
df = pd.DataFrame(data, columns=['weekday',
        'Person 1', 'Person 2', 'Person 3'])

# %%
df
# Out:
#      weekday  Person 1  Person 2  Person 3
# 0     Monday        12        10         8
# 1    Tuesday         6         6         5
# 2  Wednesday         5        11         7
# 3   Thursday         8         5         3
# 4     Friday        11         8         7
# 5   Saturday         6         9        11
# 6     Sunday         4        12        15

# %% [markdown]
# Realizamos la agrupación por día de la semana y por la nueva variable persona.

# %%
melted = pd.melt(df, id_vars=["weekday"], 
                 var_name="Person", value_name="Score")

# %%
melted
# Out:
#       weekday    Person  Score
# 0      Monday  Person 1     12
# 1     Tuesday  Person 1      6
# 2   Wednesday  Person 1      5
# 3    Thursday  Person 1      8
# 4      Friday  Person 1     11
# 5    Saturday  Person 1      6
# 6      Sunday  Person 1      4
# 7      Monday  Person 2     10
# 8     Tuesday  Person 2      6
# 9   Wednesday  Person 2     11
# 10   Thursday  Person 2      5
# 11     Friday  Person 2      8
# 12   Saturday  Person 2      9
# 13     Sunday  Person 2     12
# 14     Monday  Person 3      8
# 15    Tuesday  Person 3      5
# 16  Wednesday  Person 3      7
# 17   Thursday  Person 3      3
# 18     Friday  Person 3      7
# 19   Saturday  Person 3     11
# 20     Sunday  Person 3     15

# %% [markdown]
# # Ejercicios

# %% [markdown]
# ## Ejercicio 1
#
# Dado el fichero de datos datasets/chipotle.tsv

# %%
chipo = pd.read_csv('/content/drive/My Drive/Data/chipotle.tsv', sep= '\t')

chipo.head()

# %% [markdown]
# - a. Cargue el fichero en un dataframe y estudie las estructura de los datos
# - b. Transforme la columna item_price a float.
# - c. Cuantos productos cuestan más de 10$
# - d. ¿Cual es la cantidad del producto más caro ordenado?
# - e. ¿Cuantas veces los cientes consumen más de una Canned Soda?

# %% [markdown]
# ##### Solución Ejercicio 1

# %% [markdown]
# Cargue el fichero en un dataframe y estudie las estructura de los datos

# %%
chipo = spark.read.csv(DATA_PATH+'chipotle.tsv', sep='\t').toPandas()

# chipo = pd.read_csv('datasets/chipotle.tsv', sep = '\t')

# %%
chipo.describe(include='all')
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %%
chipo.head(3)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
# 2         1         1              Nantucket Nectar            [Apple]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39

# %% [markdown]
# Transforme la columna item_price a float

# %%
prices = [float(value[1 : -1]) for value in chipo.item_price]

chipo.item_price = prices 
chipo.head(3)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
# 2         1         1              Nantucket Nectar            [Apple]
#
#    item_price
# 0        2.39
# 1        3.39
# 2        3.39

# %% [markdown]
# Cuantos productos cuestan más de 10$

# %%
chipo10 = chipo[chipo['item_price'] > 10.00]
chipo10.head()

len(chipo10)

# %% [markdown]
# ¿Cual es la cantidad del producto más caro ordenado?

# %%
chipo.sort_values(by = "item_price", ascending = False).head(1)

# %% [markdown]
# ¿Cuantas veces los cientes consumen más de una Canned Soda?

# %%
chipo_drink_steak_bowl = chipo[(chipo.item_name == "Canned Soda") & (chipo.quantity > 1)]
len(chipo_drink_steak_bowl)

# %% [markdown]
# ## Ejercicio 2
#
# Dado el fichero de datos datasets/iris.data

# %% [markdown]
# - a. Cargue el fichero en un dataframe y estudie las estructura de los datos
# - b. Asigne a las columnas los siguientes nombres: sepal_length, sepal_width, petal_length, petal_width y class
# - c. Elimine la columna class
# - d. Asigne valores nulos a las 3 primeras filas y después elimíne las filas con NaNs
# - e. Reinicie el índice de los registros

# %% [markdown]
# Cargue el fichero en un dataframe y estudie las estructura de los datos

# %%
iris = pd.read_csv('datasets/iris.data', header=None)

iris.head()

# %% [markdown]
# Asigne a las columnas los siguientes nombres: sepal_length, sepal_width, petal_length, petal_width y class

# %%
iris.columns = ['sepal_length','sepal_width', 'petal_length', 'petal_width', 'class']
iris.head()

# %% [markdown]
# Elimine la columna class

# %%
del iris['class']
iris.head()

# %% [markdown]
# Asigne valores nulos a las 3 primeras filas y después elimíne las filas con NaNs

# %%
iris.iloc[0:3 ,:] = np.nan
iris.head()

# %%
iris = iris.dropna(how='any')
iris.head()

# %% [markdown]
# Reinicie el índice de los registros

# %%
iris = iris.reset_index(drop = True)
iris.head()

# %% [markdown]
# ## Ejercicio 3
#
# Dado el dataset /datasets/worldstats.csv

# %% [markdown]
# - a. Cargue el fichero en un dataframe y estudie las estructura de los datos.
# - b. Reasigne el índice  de modo que el DF resultante tenga el país y el año como índice de los registros
# - c. Modifique la estructura del DF de modo que por cada registro haya un único valor para Population y GDP

# %% [markdown]
# Cargue el fichero en un dataframe y estudie las estructura de los datos.

# %%
world = pd.read_csv('datasets/worldstats.csv')
world.head(3)

# %% [markdown]
# Reasigne el índice  de modo que el DF resultante tenga el país y el año como índice de los registros

# %%
world.set_index(['country','year'],inplace=True)
world

# %% [markdown]
# Modifique la estructura del DF de modo que por cada registro haya un único valor para Population y GDP

# %%
world.stack()
